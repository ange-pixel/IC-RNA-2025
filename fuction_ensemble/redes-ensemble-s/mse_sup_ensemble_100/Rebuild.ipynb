# %%
# !pip install tf-levenberg-marquardt
# Out:
# Requirement already satisfied: tf-levenberg-marquardt in /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages (1.0.3)
# Requirement already satisfied: numpy>=1.22 in /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages (from tf-levenberg-marquardt) (1.26.4)
# Requirement already satisfied: tensorflow>=2.15.0 in /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages (from tf-levenberg-marquardt) (2.15.0)
# Requirement already satisfied: absl-py>=1.0.0 in /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages (from tensorflow>=2.15.0->tf-levenberg-marquardt) (2.2.2)
# Requirement already satisfied: astunparse>=1.6.0 in /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages (from tensorflow>=2.15.0->tf-levenberg-marquardt) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages (from tensorflow>=2.15.0->tf-levenberg-marquardt) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages (from tensorflow>=2.15.0->tf-levenberg-marquardt) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages (from tensorflow>=2.15.0->tf-levenberg-marquardt) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages (from tensorflow>=2.15.0->tf-levenberg-marquardt) (3.13.0)
# Requirement already satisfied: libclang>=13.0.0 in /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages (from tensorflow>=2.15.0->tf-levenberg-marquardt) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.2.0 in /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages (from tensorflow>=2.15.0->tf-levenberg-marquardt) (0.2.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages (from tensorflow>=2.15.0->tf-levenberg-marquardt) (3.4.0)
# Requirement already satisfied: packaging in /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages (from tensorflow>=2.15.0->tf-levenberg-marquardt) (25.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages (from tensorflow>=2.15.0->tf-levenberg-marquardt) (4.25.8)
# Requirement already satisfied: setuptools in /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages (from tensorflow>=2.15.0->tf-levenberg-marquardt) (78.1.1)
# Requirement already satisfied: six>=1.12.0 in /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages (from tensorflow>=2.15.0->tf-levenberg-marquardt) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages (from tensorflow>=2.15.0->tf-levenberg-marquardt) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages (from tensorflow>=2.15.0->tf-levenberg-marquardt) (4.13.2)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages (from tensorflow>=2.15.0->tf-levenberg-marquardt) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages (from tensorflow>=2.15.0->tf-levenberg-marquardt) (0.37.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages (from tensorflow>=2.15.0->tf-levenberg-marquardt) (1.71.0)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages (from tensorflow>=2.15.0->tf-levenberg-marquardt) (2.15.2)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages (from tensorflow>=2.15.0->tf-levenberg-marquardt) (2.15.0)
# Requirement already satisfied: keras<2.16,>=2.15.0 in /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages (from tensorflow>=2.15.0->tf-levenberg-marquardt) (2.15.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages (from tensorboard<2.16,>=2.15->tensorflow>=2.15.0->tf-levenberg-marquardt) (2.40.2)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages (from tensorboard<2.16,>=2.15->tensorflow>=2.15.0->tf-levenberg-marquardt) (1.2.2)
# Requirement already satisfied: markdown>=2.6.8 in /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages (from tensorboard<2.16,>=2.15->tensorflow>=2.15.0->tf-levenberg-marquardt) (3.8)
# Requirement already satisfied: requests<3,>=2.21.0 in /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages (from tensorboard<2.16,>=2.15->tensorflow>=2.15.0->tf-levenberg-marquardt) (2.32.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages (from tensorboard<2.16,>=2.15->tensorflow>=2.15.0->tf-levenberg-marquardt) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages (from tensorboard<2.16,>=2.15->tensorflow>=2.15.0->tf-levenberg-marquardt) (3.1.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow>=2.15.0->tf-levenberg-marquardt) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow>=2.15.0->tf-levenberg-marquardt) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow>=2.15.0->tf-levenberg-marquardt) (4.9.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow>=2.15.0->tf-levenberg-marquardt) (2.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow>=2.15.0->tf-levenberg-marquardt) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow>=2.15.0->tf-levenberg-marquardt) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow>=2.15.0->tf-levenberg-marquardt) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow>=2.15.0->tf-levenberg-marquardt) (2025.4.26)
# Requirement already satisfied: pyasn1>=0.1.3 in /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages (from rsa<5,>=3.1.4->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow>=2.15.0->tf-levenberg-marquardt) (0.6.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages (from astunparse>=1.6.0->tensorflow>=2.15.0->tf-levenberg-marquardt) (0.45.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow>=2.15.0->tf-levenberg-marquardt) (3.2.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow>=2.15.0->tf-levenberg-marquardt) (3.0.2)

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

scaler = StandardScaler()
out_scaler = StandardScaler()
input_scaler = StandardScaler()

def peaks(grid):
    x = np.linspace(0, 1, grid)
    y = np.linspace(0, 1, grid) 
    x, y = np.meshgrid(x, y)
    z = 1.3356 * (1.5 * (1 - x))+np.exp(2 * x - 1) * np.sin(3 * np.pi * (x - 0.6)**2)+np.exp(3*(y - 0.5)) * np.sin(4 * np.pi * (y - 0.9)**2)
    return x, y, z

def create_dataframe(grid):
   x, y, z = peaks(grid)
   data = {'X': x.flatten(), 'Y': y.flatten(), 'Z': z.flatten()}
   df = pd.DataFrame(data)
   return df

def show_norm(df, label="Peaks", plot=False):
    df_norm = pd.DataFrame(scaler.fit_transform(df), columns=df.columns)
    df_denorm = pd.DataFrame(scaler.inverse_transform(df_norm), columns=df_norm.columns)

    if (plot):
        df.plot(title=f"{label}: Original data")
        df_norm.plot(title=f"{label}: Normalized data")
        df_denorm.plot(title=f"{label}: Denormalized data")
    return (df_norm)

def test_out_scaler(df):
    out = df["Z"].values.reshape(-1, 1)  
    plt.plot(out, label='Original')
    out_scaler.fit(out)
    norm = out_scaler.transform(out)
    plt.plot(norm, label='Normalizado')
    denorm = out_scaler.inverse_transform(norm)
    plt.plot(denorm, label='desnormalizado')
    plt.legend()
    plt.show()

def split_df(df):
    _input = np.vstack([df['X'], df['Y']]).T
    _output = np.array(df['Z'])
    return (_input, _output)

df_25 = create_dataframe(grid=5)
df_25_norm = show_norm(df_25)
test_out_scaler(df_25)

df_1000 = create_dataframe(grid=32)
df_1000_norm = show_norm(df_1000)

_input, _output = split_df(df_25)
input_scaler.fit(_input)
# Out:
# StandardScaler()

# %%
import tensorflow as tf
import numpy as np
from keras import regularizers
from keras import initializers
import tf_levenberg_marquardt as lm

# layers, neurons
class ShuffleArchitecture:
    def __init__(self, input_size, hidden_sizes, output_size, act_h, act_o, param_reg):
        self.input_size = input_size
        self.hidden_sizes = hidden_sizes
        self.output_size = output_size
        self.act_h = act_h
        self.act_o = act_o
        self.regularizer = regularizers.L2(param_reg)
        self.initializer = initializers.RandomUniform(minval=-0.5, maxval=0.5, seed=np.random.randint(1, 10000))

    def compute_k(self):
        total_parameters = 0
        for layer in self.model.layers:
            weights = layer.get_weights()
            if len(weights) > 0:  
                for w in weights:
                    total_parameters += np.prod(w.shape)
        return total_parameters
        
    def set_architecture(self):
        self.model = tf.keras.Sequential()
        self.model.add(tf.keras.layers.Dense(self.hidden_sizes[0],
                        input_shape=(self.input_size,),
                        activation=self.act_h,
                        kernel_regularizer=self.regularizer,
                        kernel_initializer=self.initializer,                        
                        ))  # input layer

        for size in self.hidden_sizes[1:]:  # hidden layers
            self.model.add(tf.keras.layers.Dense(size,
                            activation=self.act_h,
                            kernel_regularizer=self.regularizer,
                            kernel_initializer=self.initializer,  
                        ))

        self.model.add(tf.keras.layers.Dense(self.output_size,
                        activation=self.act_o,
                        kernel_regularizer=self.regularizer,
                        kernel_initializer=self.initializer,  
                        ))  # output layer

    def create_model(self, _learning_rate):
        mse_loss = lm.loss.MeanSquaredError()

        self.model.compile(
            optimizer=tf.keras.optimizers.Adam(learning_rate=_learning_rate),
            loss=tf.keras.losses.MeanSquaredError(),
        )
        self.lm_model = lm.model.ModelWrapper(
            tf.keras.models.clone_model(self.model)
        )
        self.lm_model.compile(
            optimizer=tf.keras.optimizers.SGD(learning_rate=_learning_rate),
             loss=lm.loss.MeanSquaredError()
        )
        return self.lm_model
# Out:
# 2025-06-04 12:13:31.155762: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-06-04 12:13:31.199847: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-06-04 12:13:31.199892: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-06-04 12:13:31.201658: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-06-04 12:13:31.209580: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-06-04 12:13:31.210326: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-06-04 12:13:32.094109: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
import pickle
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn.metrics import r2_score, mean_squared_error, root_mean_squared_error, mean_absolute_percentage_error 
import plotly.figure_factory as ff
import plotly.offline as py
from scipy.spatial import Delaunay
import plotly.graph_objs as go


class Rebuild:
    def __init__(self):
        self.df = pd.read_excel(f"better_results_03.xlsx")        
        self.sup_input, self.sup_output = split_df(df_1000_norm)
        self.matriz= np.empty((0, 0))

    def LoadModelWeights(self, model, fileName):        
        path = f"content/models/{fileName}.keras"
        model.load_weights(path)

    def LoadPrevDataset(self, fileName):
        fileName = fileName.replace("model", "dataset")
        pos = fileName.rfind("_")
        path = f"content/dataset/{fileName[:pos]}.pkl" 
        with open(path, 'rb') as f:
            _data, _train, _vt, _val, _test = pickle.load(f)
        self._data, self._train, self._vt, self._val, self._test = _data, _train, _vt, _val, _test    
    
    def setArchitecture(self, _hidden_sizes, _pg, _lr):
        shuffler = ShuffleArchitecture(input_size = 2,
                                    hidden_sizes = _hidden_sizes,
                                    output_size = 1,
                                    act_h = 'tanh',
                                    act_o = 'linear',
                                    param_reg = _pg)
        shuffler.set_architecture()
        self.k = shuffler.compute_k()
        return(shuffler.create_model(_lr))            

    def getArchitecture(self, architecture):
        hidden_size = [int(x) for x in architecture.split("[")[1].split("]")[0].split(", ")]
        regularizer = float(architecture.split("regularizer=")[1].split(",")[0])
        learning_rate = float(architecture.split("learning_rate=")[1])
        return hidden_size, regularizer, learning_rate

    def PlotResults(self, original_values, predicted_values):
        titles = ['Original vs. Preditos (Completo)',
                    'Original vs. Preditos (Teste)',
                    'Original vs. Preditos (Validação)',
                    'Original vs. Preditos (Validação e Teste)']
        fig, axes = plt.subplots(2, 2, figsize=(12, 8))
        for i, ax in enumerate(axes.flat):
            ax.plot(original_values[i], label='Original')
            ax.plot(predicted_values[i], label='Preditos')
            ax.set_title(titles[i])
            ax.legend()
        plt.tight_layout()
        plt.show()

    def matriz_Z_pred(self,predicted_values):
        
        if self.matriz.size == 0:
            # Inicializa a matriz com o primeiro vetor como a primeira coluna
            self.matriz = np.expand_dims(predicted_values, axis=1)
        else:
            # Verifica se o vetor tem o mesmo número de linhas que a matriz
            if self.matriz.shape[0] == predicted_values.shape[0]:
                # Expande a matriz com o novo vetor como uma nova coluna
                self.matriz = np.column_stack((self.matriz, predicted_values))
       
    def get_matrix(self):
        # Retorna a matriz atual
        return self.matriz
    
    def sum_rows_and_divide_by_10(self, original_values):
        if self.matriz.size == 10:
            row_sums = np.sum(self.matriz, axis=1)
            row_sums_divided = np.zeros_like(row_sums)
            row_sums_divided = row_sums / 10
            coluna_np = np.array(row_sums_divided)
            coluna_np1=np.expand_dims(coluna_np, axis=1) 
            x, y, z = df_1000['X'], df_1000['Y'], df_1000['Z']
            points = np.column_stack((x, y))
            tri = Delaunay(points)
            
            fig_original = ff.create_trisurf(x=x, y=y, z=original_values.flatten(), 
                                            simplices=tri.simplices, colormap='Greys',
                                            title='Surface Fit - Original Values')

            fig_predicted = ff.create_trisurf(x=x, y=y, z=coluna_np1, 
                                            simplices=tri.simplices, colormap='Viridis',
                                            title='Surface Fit - Predicted Values')

            data = [fig_original.data[0], fig_predicted.data[0], ]
            fig = go.Figure(data=data)
            fig.update_layout(title='Surface Fit', autosize=False,
                    width=500, height=500,
                    margin=dict(l=65, r=50, b=65, t=90))
            fig.show()

    def PlotSurface(self, original_values, predicted_values, model):
        x, y, z = df_1000['X'], df_1000['Y'], df_1000['Z']
        points = np.column_stack((x, y))
        tri = Delaunay(points)
        
        fig_original = ff.create_trisurf(x=x, y=y, z=original_values.flatten(), 
                                        simplices=tri.simplices, colormap='Greys',
                                        title='Surface Fit - Original Values')

        fig_predicted = ff.create_trisurf(x=x, y=y, z=predicted_values.flatten(), 
                                        simplices=tri.simplices, colormap='Viridis',
                                        title='Surface Fit - Predicted Values')

        data = [fig_original.data[0], fig_predicted.data[0], ]
        fig = go.Figure(data=data)
        fig.update_layout(title='Surface Fit', autosize=False,
                  width=500, height=500,
                  margin=dict(l=65, r=50, b=65, t=90))
        fig.show()

    def get_new_metrics(self, orig, pred, r2, mse):
      n = len(orig) # N: quantidade de saidas
      k = self.k
      waste = (orig.flatten() - pred.flatten())

      mape = mean_absolute_percentage_error(orig, pred)  
      r2_adj = 1 - (((n - 1)/(n - k - 1)) * (1 - r2))
      rsd = np.sqrt(np.sum(waste ** 2) / (n - 2))
      rmse = root_mean_squared_error(orig, pred)          
      aic = (-2 * np.log(mse)) + (2 * k)
      bic = (-2 * np.log(mse)) + (k * np.log(n))
      return (mape, r2_adj, rsd, rmse, aic, bic)

    def RecalcMetrics(self, idx,
                        out_denorm, test_denorm, val_denorm, vt_denorm, sup_denorm,
                        pred_denorm, test_pred_denorm, val_pred_denorm, vt_pred_denorm, sup_pred_denorm):
        r2 = r2_score(out_denorm, pred_denorm)
        r2_test = r2_score(test_denorm, test_pred_denorm)
        r2_val = r2_score(val_denorm, val_pred_denorm)
        r2_vt = r2_score(vt_denorm,  vt_pred_denorm)
        r2_sup = r2_score(sup_denorm,  sup_pred_denorm)

        mse = mean_squared_error(out_denorm, pred_denorm)
        mse_test = mean_squared_error(test_denorm, test_pred_denorm)
        mse_val = mean_squared_error(val_denorm, val_pred_denorm)
        mse_vt = mean_squared_error(vt_denorm,  vt_pred_denorm)
        mse_sup = mean_squared_error(sup_denorm,  sup_pred_denorm)
        
        mape, r2_adj, rsd, rmse, aic, bic = self.get_new_metrics(out_denorm, pred_denorm, r2, mse)
        self.df.loc[idx, 'r2'] = r2
        self.df.loc[idx, 'r2_sup'] = r2_sup
        self.df.loc[idx, 'r2_test'] = r2_test
        self.df.loc[idx, 'r2_val'] = r2_val
        self.df.loc[idx, 'r2_vt'] = r2_vt
        self.df.loc[idx, 'mse'] = mse
        self.df.loc[idx, 'mse_sup'] = mse_sup
        self.df.loc[idx, 'mse_test'] = mse_test
        self.df.loc[idx, 'mse_val'] = mse_val
        self.df.loc[idx, 'mse_vt'] = mse_vt
        self.df.loc[idx, 'mape'] = mape
        self.df.loc[idx, 'rmse'] = rmse
        self.df.loc[idx, 'r2_adj'] = r2_adj
        self.df.loc[idx, 'rsd'] = rsd
        self.df.loc[idx, 'aic'] = aic
        self.df.loc[idx, 'bic'] = bic

    def print_MSE(self, original_values, predicted_values):
        MSE_sup= mean_squared_error(original_values,predicted_values)
        mse_sup = f"\nMSE de superficie: {MSE_sup}\n"
        return mse_sup

    
    def GetOuts(self, df, out_denorm, pred_denorm, fileName):
        input, output = split_df(df)
        
        data = {'X': input[:, 0].flatten(),
                'Y': input[:, 0].flatten(),
                'Z': out_denorm.flatten(),
                'Z_pred': pred_denorm.flatten()}
        
        df = pd.DataFrame(data)
        df.to_excel(f"{fileName}.xlsx", index=False)


    def predictResults(self, idx=-1):
        pred = self.lm_model.predict(self._data[0]).flatten()
        test_pred = self.lm_model.predict(self._test[0]).flatten()
        val_pred = self.lm_model.predict(self._val[0]).flatten()
        vt_pred = self.lm_model.predict(self._vt[0]).flatten()
        sup_pred = self.lm_model.predict(self.sup_input).flatten()

        # Calculando as metricas com a saida desnormalizada
        pred_denorm = out_scaler.inverse_transform(pred.reshape(-1, 1))
        test_pred_denorm = out_scaler.inverse_transform(test_pred.reshape(-1, 1))
        val_pred_denorm = out_scaler.inverse_transform(val_pred.reshape(-1, 1))
        vt_pred_denorm = out_scaler.inverse_transform(vt_pred.reshape(-1, 1))
        sup_pred_denorm = out_scaler.inverse_transform(sup_pred.reshape(-1, 1))

        out_denorm = out_scaler.inverse_transform(self._data[1].reshape(-1, 1))
        test_denorm = out_scaler.inverse_transform(self._test[1].reshape(-1, 1))
        val_denorm = out_scaler.inverse_transform(self._val[1].reshape(-1, 1))
        vt_denorm = out_scaler.inverse_transform(self._vt[1].reshape(-1, 1))
        sup_denorm = out_scaler.inverse_transform(self.sup_output.reshape(-1, 1))

        original_values = [out_denorm, test_denorm, val_denorm, vt_denorm, sup_denorm]
        predicted_values = [pred_denorm, test_pred_denorm, val_pred_denorm, vt_pred_denorm, sup_pred_denorm]

        if (idx != -1):
            self.RecalcMetrics(idx,
                                out_denorm, test_denorm, val_denorm, vt_denorm, sup_denorm,
                                pred_denorm, test_pred_denorm, val_pred_denorm, vt_pred_denorm, sup_pred_denorm)            
        return (original_values, predicted_values)


    def FixWrongMetrics(self):
        i = 0
        for file_model, architecture in zip(self.df["model"], self.df["Architecture"]):
            hidden_size, regularizer, learning_rate = self.getArchitecture(architecture)
            self.lm_model = self.setArchitecture(hidden_size, regularizer, learning_rate)
            self.LoadModelWeights(self.lm_model, file_model)
            self.LoadPrevDataset(file_model)
            original_values, predicted_values = self.predictResults(i)
            i += 1
        self.df.to_excel("fixed_results.xlsx", index=False)

    def rebuildFullNet(self, model):
        for file_model, architecture in zip(self.df["model"], self.df["Architecture"]):
            if model == file_model:
                hidden_size, regularizer, learning_rate = self.getArchitecture(architecture)
                self.lm_model = self.setArchitecture(hidden_size, regularizer, learning_rate)
                self.LoadModelWeights(self.lm_model, file_model)
                self.LoadPrevDataset(file_model)
                original_values, predicted_values = self.predictResults()
                self.PlotSurface(original_values[4], predicted_values[4], model)
                self.GetOuts(df_25, original_values[0], predicted_values[0], f"25_{model}")
                self.GetOuts(df_1000, original_values[4], predicted_values[4], f"1000_{model}")
                mse_pred=self.print_MSE(original_values[4], predicted_values[4])
                print(f" {mse_pred}")
                #self.matriz_Z_pred(predicted_values[4])
                #matriz= self.get_matrix()
                #print(matriz)
                #self.sum_rows_and_divide_by_10(original_values[4])
                #mse_pred_med=self.print_MSE(original_values[4], med_z_pred)
                #print(f" media: {mse_pred_med}")

# %%
Rebuilder = Rebuild()
Rebuilder.FixWrongMetrics()
# Out:
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 21ms/step
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 23ms/step
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 15ms/step
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 17ms/step
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 32/32 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 28ms/step
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 14ms/step
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 20ms/step
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 15ms/step
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 23ms/step
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 15ms/step
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 15ms/step
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 16ms/step
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 18ms/step
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 15ms/step
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 19ms/step
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 14ms/step
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 32/32 [==============================] - 0s 2ms/step

# %%
Rebuilder = Rebuild()
Rebuilder.rebuildFullNet("model_2_3_1")
# Out:
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 32/32 [==============================] - 0s 2ms/step
#
# MSE de superficie: 0.20281607015879802

# %%
Rebuilder = Rebuild()
Rebuilder.rebuildFullNet("model_2_3_2")
# Out:
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 31ms/step
# 32/32 [==============================] - 0s 4ms/step
#
# MSE de superficie: 0.2026722509726634

# %%
Rebuilder = Rebuild()
Rebuilder.rebuildFullNet("model_2_3_3")
# Out:
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 32/32 [==============================] - 0s 2ms/step
#
# MSE de superficie: 0.20254100837151756

# %%
Rebuilder = Rebuild()
Rebuilder.rebuildFullNet("model_2_3_4")
# Out:
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 32/32 [==============================] - 0s 2ms/step
#
# MSE de superficie: 0.20254236537253198

# %%
Rebuilder = Rebuild()
Rebuilder.rebuildFullNet("model_6_2_2")
# Out:
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 32/32 [==============================] - 0s 2ms/step
#
# MSE de superficie: 0.21298610971820323

# %%
Rebuilder = Rebuild()
Rebuilder.rebuildFullNet("model_6_2_3")
# Out:
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 32/32 [==============================] - 0s 2ms/step
#
# MSE de superficie: 0.21454390653663305

# %%
Rebuilder = Rebuild()
Rebuilder.rebuildFullNet("model_12_1_15")
# Out:
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 19ms/step
# 32/32 [==============================] - 0s 2ms/step
#
# MSE de superficie: 0.21259491226644878

# %%
Rebuilder = Rebuild()
Rebuilder.rebuildFullNet("model_12_1_16")
# Out:
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 25ms/step
# 32/32 [==============================] - 0s 2ms/step
#
# MSE de superficie: 0.21338140529322067

# %%
Rebuilder = Rebuild()
Rebuilder.rebuildFullNet("model_20_5_4")
# Out:
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 32/32 [==============================] - 0s 2ms/step
#
# MSE de superficie: 0.21768432459192122

# %%
Rebuilder = Rebuild()
Rebuilder.rebuildFullNet("model_20_5_5")
# Out:
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# 32/32 [==============================] - 0s 4ms/step
#
# MSE de superficie: 0.21791378484196272

# %%
Rebuilder = Rebuild()
Rebuilder.rebuildFullNet("model_24_4_21")
# Out:
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 32/32 [==============================] - 0s 2ms/step
#
# MSE de superficie: 0.21787957021232313

# %%
Rebuilder = Rebuild()
Rebuilder.rebuildFullNet("model_24_4_22")
# Out:
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 32/32 [==============================] - 0s 2ms/step
#
# MSE de superficie: 0.21787728000286136

# %%
Rebuilder = Rebuild()
Rebuilder.rebuildFullNet("model_24_4_23")
# Out:
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 17ms/step
# 32/32 [==============================] - 0s 2ms/step
#
# MSE de superficie: 0.21787574479162813

# %%
Rebuilder = Rebuild()
Rebuilder.rebuildFullNet("model_24_4_24")
# Out:
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 36ms/step
# 32/32 [==============================] - 0s 2ms/step
#
# MSE de superficie: 0.2178739293897248

# %%
Rebuilder = Rebuild()
Rebuilder.rebuildFullNet("model_34_4_10")
# Out:
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 32/32 [==============================] - 0s 2ms/step
#
# MSE de superficie: 0.20552806479036495

# %%
Rebuilder = Rebuild()
Rebuilder.rebuildFullNet("model_34_4_11")
# Out:
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 32/32 [==============================] - 0s 2ms/step
#
# MSE de superficie: 0.20558802263880552

# %%
Rebuilder = Rebuild()
Rebuilder.rebuildFullNet("model_38_9_24")
# Out:
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 32/32 [==============================] - 0s 3ms/step
#
# MSE de superficie: 0.20968067430390824

# %%
Rebuilder = Rebuild()
Rebuilder.rebuildFullNet("model_38_9_24")
# Out:
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 32/32 [==============================] - 0s 2ms/step
#
# MSE de superficie: 0.20968067430390824

# %%
Rebuilder = Rebuild()
Rebuilder.rebuildFullNet("model_4_8_2")
# Out:
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 32/32 [==============================] - 0s 2ms/step
#
# MSE de superficie: 0.2259444386662576

# %%
Rebuilder = Rebuild()
Rebuilder.rebuildFullNet("model_4_8_3")
# Out:
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 32/32 [==============================] - 0s 3ms/step
#
# MSE de superficie: 0.22594444171727524

# %%
Rebuilder = Rebuild()
Rebuilder.rebuildFullNet("model_8_4_5")
# Out:
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 32/32 [==============================] - 0s 3ms/step
#
# MSE de superficie: 0.22068205570738741

# %%
Rebuilder = Rebuild()
Rebuilder.rebuildFullNet("model_8_4_6")
# Out:
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 15ms/step
# 32/32 [==============================] - 0s 3ms/step
#
# MSE de superficie: 0.22068205570738741

# %%
Rebuilder = Rebuild()
Rebuilder.rebuildFullNet("model_8_4_8")
# Out:
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 32/32 [==============================] - 0s 4ms/step
#
# MSE de superficie: 0.22068205570738741

# %%
Rebuilder = Rebuild()
Rebuilder.rebuildFullNet("model_8_4_9")
# Out:
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 32/32 [==============================] - 0s 2ms/step
#
# MSE de superficie: 0.22068205570738741

# %%
Rebuilder = Rebuild()
Rebuilder.rebuildFullNet("model_8_4_13")
# Out:
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 32/32 [==============================] - 0s 2ms/step
#
# MSE de superficie: 0.22068205570738741

# %%
Rebuilder = Rebuild()
Rebuilder.rebuildFullNet("model_10_7_10")
# Out:
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 32/32 [==============================] - 0s 2ms/step
#
# MSE de superficie: 0.2539288165768551

# %%
Rebuilder = Rebuild()
Rebuilder.rebuildFullNet("model_12_8_1")
# Out:
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 23ms/step
# 32/32 [==============================] - 0s 3ms/step
#
# MSE de superficie: 0.22127167321248575

# %%
Rebuilder = Rebuild()
Rebuilder.rebuildFullNet("model_12_8_18")
# Out:
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 23ms/step
# 32/32 [==============================] - 0s 3ms/step
#
# MSE de superficie: 0.22129445940197512

# %%
Rebuilder = Rebuild()
Rebuilder.rebuildFullNet("model_12_8_19")
# Out:
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 32/32 [==============================] - 0s 3ms/step
#
# MSE de superficie: 0.22129484947575534

# %%
Rebuilder = Rebuild()
Rebuilder.rebuildFullNet("model_12_8_20")
# Out:
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 32/32 [==============================] - 0s 3ms/step
#
# MSE de superficie: 0.22129517863213027

# %%
Rebuilder = Rebuild()
Rebuilder.rebuildFullNet("model_12_8_21")
# Out:
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 33ms/step
# 32/32 [==============================] - 0s 3ms/step
#
# MSE de superficie: 0.22129582983790524

# %%
Rebuilder = Rebuild()
Rebuilder.rebuildFullNet("model_15_9_1")
# Out:
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 59ms/step
# 32/32 [==============================] - 0s 3ms/step
#
# MSE de superficie: 0.2165971535623766

# %%
Rebuilder = Rebuild()
Rebuilder.rebuildFullNet("model_15_9_2")
# Out:
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 32/32 [==============================] - 0s 2ms/step
#
# MSE de superficie: 0.21659733910517254

# %%
Rebuilder = Rebuild()
Rebuilder.rebuildFullNet("model_20_9_20")
# Out:
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 32/32 [==============================] - 0s 3ms/step
#
# MSE de superficie: 0.2036376695582144

# %%
Rebuilder = Rebuild()
Rebuilder.rebuildFullNet("model_20_9_22")
# Out:
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 32/32 [==============================] - 0s 2ms/step
#
# MSE de superficie: 0.20363704923724005

# %%
Rebuilder = Rebuild()
Rebuilder.rebuildFullNet("model_20_9_23")
# Out:
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 32/32 [==============================] - 0s 3ms/step
#
# MSE de superficie: 0.203636702783983

# %%
Rebuilder = Rebuild()
Rebuilder.rebuildFullNet("model_22_9_8")
# Out:
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 22ms/step
# 32/32 [==============================] - 0s 2ms/step
#
# MSE de superficie: 0.2059761681586699

# %%
Rebuilder = Rebuild()
Rebuilder.rebuildFullNet("model_22_9_9")
# Out:
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 32/32 [==============================] - 0s 3ms/step
#
# MSE de superficie: 0.20608249340805473
