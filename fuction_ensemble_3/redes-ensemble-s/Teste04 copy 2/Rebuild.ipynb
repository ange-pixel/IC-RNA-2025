# %%
# !pip install tf-levenberg-marquardt
# Out:
# Requirement already satisfied: tf-levenberg-marquardt in /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages (1.0.3)
# Requirement already satisfied: numpy>=1.22 in /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages (from tf-levenberg-marquardt) (2.1.3)
# Requirement already satisfied: tensorflow>=2.15.0 in /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages (from tf-levenberg-marquardt) (2.19.0)
# Requirement already satisfied: absl-py>=1.0.0 in /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages (from tensorflow>=2.15.0->tf-levenberg-marquardt) (2.2.2)
# Requirement already satisfied: astunparse>=1.6.0 in /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages (from tensorflow>=2.15.0->tf-levenberg-marquardt) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages (from tensorflow>=2.15.0->tf-levenberg-marquardt) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages (from tensorflow>=2.15.0->tf-levenberg-marquardt) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages (from tensorflow>=2.15.0->tf-levenberg-marquardt) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages (from tensorflow>=2.15.0->tf-levenberg-marquardt) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages (from tensorflow>=2.15.0->tf-levenberg-marquardt) (3.4.0)
# Requirement already satisfied: packaging in /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages (from tensorflow>=2.15.0->tf-levenberg-marquardt) (25.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages (from tensorflow>=2.15.0->tf-levenberg-marquardt) (5.29.4)
# Requirement already satisfied: requests<3,>=2.21.0 in /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages (from tensorflow>=2.15.0->tf-levenberg-marquardt) (2.32.3)
# Requirement already satisfied: setuptools in /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages (from tensorflow>=2.15.0->tf-levenberg-marquardt) (78.1.1)
# Requirement already satisfied: six>=1.12.0 in /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages (from tensorflow>=2.15.0->tf-levenberg-marquardt) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages (from tensorflow>=2.15.0->tf-levenberg-marquardt) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages (from tensorflow>=2.15.0->tf-levenberg-marquardt) (4.13.2)
# Requirement already satisfied: wrapt>=1.11.0 in /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages (from tensorflow>=2.15.0->tf-levenberg-marquardt) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages (from tensorflow>=2.15.0->tf-levenberg-marquardt) (1.71.0)
# Requirement already satisfied: tensorboard~=2.19.0 in /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages (from tensorflow>=2.15.0->tf-levenberg-marquardt) (2.19.0)
# Requirement already satisfied: keras>=3.5.0 in /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages (from tensorflow>=2.15.0->tf-levenberg-marquardt) (3.9.2)
# Requirement already satisfied: h5py>=3.11.0 in /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages (from tensorflow>=2.15.0->tf-levenberg-marquardt) (3.13.0)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.5.1 in /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages (from tensorflow>=2.15.0->tf-levenberg-marquardt) (0.5.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages (from tensorflow>=2.15.0->tf-levenberg-marquardt) (0.37.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow>=2.15.0->tf-levenberg-marquardt) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow>=2.15.0->tf-levenberg-marquardt) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow>=2.15.0->tf-levenberg-marquardt) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow>=2.15.0->tf-levenberg-marquardt) (2025.4.26)
# Requirement already satisfied: markdown>=2.6.8 in /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages (from tensorboard~=2.19.0->tensorflow>=2.15.0->tf-levenberg-marquardt) (3.8)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages (from tensorboard~=2.19.0->tensorflow>=2.15.0->tf-levenberg-marquardt) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages (from tensorboard~=2.19.0->tensorflow>=2.15.0->tf-levenberg-marquardt) (3.1.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages (from astunparse>=1.6.0->tensorflow>=2.15.0->tf-levenberg-marquardt) (0.45.1)
# Requirement already satisfied: rich in /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages (from keras>=3.5.0->tensorflow>=2.15.0->tf-levenberg-marquardt) (14.0.0)
# Requirement already satisfied: namex in /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages (from keras>=3.5.0->tensorflow>=2.15.0->tf-levenberg-marquardt) (0.0.9)
# Requirement already satisfied: optree in /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages (from keras>=3.5.0->tensorflow>=2.15.0->tf-levenberg-marquardt) (0.15.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow>=2.15.0->tf-levenberg-marquardt) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages (from rich->keras>=3.5.0->tensorflow>=2.15.0->tf-levenberg-marquardt) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages (from rich->keras>=3.5.0->tensorflow>=2.15.0->tf-levenberg-marquardt) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow>=2.15.0->tf-levenberg-marquardt) (0.1.2)

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

scaler = StandardScaler()
out_scaler = StandardScaler()
input_scaler = StandardScaler()

def  function(grid):
    x = np.linspace(-10, 10, grid)
    y = np.linspace(-10, 10, grid)
    x, y = np.meshgrid(x, y)
    z = (x + 2 * y - 7)**2 + (2 * x + y - 5)**2
    return x, y, z

def create_dataframe(grid):
   x, y, z = function(grid)
   data = {'X': x.flatten(), 'Y': y.flatten(), 'Z': z.flatten()}
   df = pd.DataFrame(data)
   return df

def show_norm(df, label="function", plot=False):
    df_norm = pd.DataFrame(scaler.fit_transform(df), columns=df.columns)
    df_denorm = pd.DataFrame(scaler.inverse_transform(df_norm), columns=df_norm.columns)

    if (plot):
        df.plot(title=f"{label}: Original data")
        df_norm.plot(title=f"{label}: Normalized data")
        df_denorm.plot(title=f"{label}: Denormalized data")
    return (df_norm)

def test_out_scaler(df):
    out = df["Z"].values.reshape(-1, 1)  
    plt.plot(out, label='Original')
    out_scaler.fit(out)
    norm = out_scaler.transform(out)
    plt.plot(norm, label='Normalizado')
    denorm = out_scaler.inverse_transform(norm)
    plt.plot(denorm, label='desnormalizado')
    plt.legend()
    plt.show()

def split_df(df):
    _input = np.vstack([df['X'], df['Y']]).T
    _output = np.array(df['Z'])
    return (_input, _output)

df_25 = create_dataframe(grid=5)
df_25_norm = show_norm(df_25)
test_out_scaler(df_25)

df_1000 = create_dataframe(grid=32)
df_1000_norm = show_norm(df_1000)

_input, _output = split_df(df_25)
input_scaler.fit(_input)
# Out:
# StandardScaler()

# %%
import tensorflow as tf
import numpy as np
from keras import regularizers
from keras import initializers
import tf_levenberg_marquardt as lm

# layers, neurons
class ShuffleArchitecture:
    def __init__(self, input_size, hidden_sizes, output_size, act_h, act_o, param_reg):
        self.input_size = input_size
        self.hidden_sizes = hidden_sizes
        self.output_size = output_size
        self.act_h = act_h
        self.act_o = act_o
        self.regularizer = regularizers.L2(param_reg)
        self.initializer = initializers.RandomUniform(minval=-0.5, maxval=0.5, seed=np.random.randint(1, 10000))

        
    def set_architecture(self):
        self.model = tf.keras.Sequential()
        self.model.add(tf.keras.layers.Dense(self.hidden_sizes[0],
                        input_shape=(self.input_size,),
                        activation=self.act_h,
                        kernel_regularizer=self.regularizer,
                        kernel_initializer=self.initializer,                        
                        ))  # input layer

        for size in self.hidden_sizes[1:]:  # hidden layers
            self.model.add(tf.keras.layers.Dense(size,
                            activation=self.act_h,
                            kernel_regularizer=self.regularizer,
                            kernel_initializer=self.initializer,  
                        ))

        self.model.add(tf.keras.layers.Dense(self.output_size,
                        activation=self.act_o,
                        kernel_regularizer=self.regularizer,
                        kernel_initializer=self.initializer,  
                        ))  # output layer

    def create_model(self, _learning_rate):

        self.model.compile(
            optimizer=tf.keras.optimizers.Adam(learning_rate=_learning_rate),
            loss='mean_squared_error',
            metrics=['mse'])

        self.lm_model = lm.model.ModelWrapper(
            tf.keras.models.clone_model(self.model))
  

        self.lm_model.compile(
            optimizer=tf.keras.optimizers.SGD(learning_rate=_learning_rate),
            loss='mean_squared_error')
        
        return(self.lm_model)

# %%
import pickle
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn.metrics import r2_score, mean_squared_error, root_mean_squared_error, mean_absolute_percentage_error 
import plotly.figure_factory as ff
import plotly.offline as py
from scipy.spatial import Delaunay
import plotly.graph_objs as go
import os


class Rebuild:
    def __init__(self):
        self.df = pd.read_excel(f"better_results.xlsx")        
        self.sup_input, self.sup_output = split_df(df_1000_norm)

    def LoadModelWeights(self, model, fileName):        
        path = f"content/models/{fileName}.keras"
        model.load_weights(path)


    def LoadPrevDataset(self, fileName):
        fileName = fileName.replace("model", "dataset")
        pos = fileName.rfind("_")
        path = f"../dataset/{fileName[:pos]}.pkl" 
        with open(path, 'rb') as f:
            _data, _train, _vt, _val, _test = pickle.load(f)
        self._data, self._train, self._vt, self._val, self._test = _data, _train, _vt, _val, _test    
    
    def setArchitecture(self, _hidden_sizes, _pg, _lr):
        shuffler = ShuffleArchitecture(input_size = 2,
                                    hidden_sizes = _hidden_sizes,
                                    output_size = 1,
                                    act_h = 'tanh',
                                    act_o = 'linear',
                                    param_reg = _pg)
        shuffler.set_architecture()
        return(shuffler.create_model(_lr))            

    def getArchitecture(self, architecture):
        hidden_size = [int(x) for x in architecture.split("[")[1].split("]")[0].split(", ")]
        regularizer = float(architecture.split("regularizer=")[1].split(",")[0])
        learning_rate = float(architecture.split("learning_rate=")[1])
        return hidden_size, regularizer, learning_rate

    def PlotResults(self, original_values, predicted_values):
        titles = ['Original vs. Preditos (Completo)',
                    'Original vs. Preditos (Teste)',
                    'Original vs. Preditos (Validação)',
                    'Original vs. Preditos (Validação e Teste)']
        fig, axes = plt.subplots(2, 2, figsize=(12, 8))
        for i, ax in enumerate(axes.flat):
            ax.plot(original_values[i], label='Original')
            ax.plot(predicted_values[i], label='Preditos')
            ax.set_title(titles[i])
            ax.legend()
        plt.tight_layout()
        plt.show()


    def predictResults(self, idx=-1):
        pred = self.lm_model.predict(self._data[0]).flatten()
        test_pred = self.lm_model.predict(self._test[0]).flatten()
        val_pred = self.lm_model.predict(self._val[0]).flatten()
        vt_pred = self.lm_model.predict(self._vt[0]).flatten()
        sup_pred = self.lm_model.predict(self.sup_input).flatten()

        # Calculando as metricas com a saida desnormalizada
        pred_denorm = out_scaler.inverse_transform(pred.reshape(-1, 1))
        test_pred_denorm = out_scaler.inverse_transform(test_pred.reshape(-1, 1))
        val_pred_denorm = out_scaler.inverse_transform(val_pred.reshape(-1, 1))
        vt_pred_denorm = out_scaler.inverse_transform(vt_pred.reshape(-1, 1))
        sup_pred_denorm = out_scaler.inverse_transform(sup_pred.reshape(-1, 1))

        out_denorm = out_scaler.inverse_transform(self._data[1].reshape(-1, 1))
        test_denorm = out_scaler.inverse_transform(self._test[1].reshape(-1, 1))
        val_denorm = out_scaler.inverse_transform(self._val[1].reshape(-1, 1))
        vt_denorm = out_scaler.inverse_transform(self._vt[1].reshape(-1, 1))
        sup_denorm = out_scaler.inverse_transform(self.sup_output.reshape(-1, 1))

        original_values = [out_denorm, test_denorm, val_denorm, vt_denorm, sup_denorm]
        predicted_values = [pred_denorm, test_pred_denorm, val_pred_denorm, vt_pred_denorm, sup_pred_denorm]

        if (idx != -1):
            self.RecalcMetrics(idx,
                                out_denorm, test_denorm, val_denorm, vt_denorm, sup_denorm,
                                pred_denorm, test_pred_denorm, val_pred_denorm, vt_pred_denorm, sup_pred_denorm)            
        return (original_values, predicted_values)

    def rebuildFullNet(self, model):
        for file_model, architecture in zip(self.df["model"], self.df["Architecture"]):
            if model == file_model:
                hidden_size, regularizer, learning_rate = self.getArchitecture(architecture)
                self.lm_model = self.setArchitecture(hidden_size, regularizer, learning_rate)
                self.LoadModelWeights(self.lm_model, file_model)
                self.LoadPrevDataset(file_model)
                original_values, predicted_values = self.predictResults()
                self.PlotResults(original_values, predicted_values)

    def create_dataset(self, input, output):
        input = tf.expand_dims(tf.cast(input, tf.float32), axis=-1)
        output = tf.expand_dims(tf.cast(output, tf.float32), axis=-1)
        dataset = tf.data.Dataset.from_tensor_slices((input, output))
        dataset = dataset.shuffle(len(input))
        dataset = dataset.batch(1000).cache()
        dataset = dataset.prefetch(tf.data.experimental.AUTOTUNE)
        return (dataset, input, output)

    def LoadNewDataset(self):
        x = np.linspace(-10, 10, 4)
        y = np.linspace(-10, 10, 4)
        x, y = np.meshgrid(x, y)
        z = (x + 2 * y - 7)**2 + (2 * x + y - 5)**2
        x = x.flatten()
        y = y.flatten()
        z = z.flatten()
        input = np.vstack([x,y]).T
        output = np.array(z)
        dataset = pd.DataFrame(input, columns=['x', 'y'])
        dataset['z'] = output
       # dataset, input, output = self.create_dataset(input, output)
        #dataset= pd.DataFrame(input,output)
        return (input, dataset)
  
    

    def mean_std(self, df):
        df_out = df.iloc[:, 2:]
        print(df)
        mean = df_out.mean(axis=1)
        std = df_out.std(axis=1)
        df["media"] = mean
        df["desvio padrao"] = std
        display(df)
        df.to_excel('results.xlsx', index=False)

    def TestNewData(self):
        input, df = self.LoadNewDataset()
        for file_model, architecture in zip(self.df["model"], self.df["Architecture"]):
            hidden_size, regularizer, learning_rate = self.getArchitecture(architecture)
            self.lm_model = self.setArchitecture(hidden_size, regularizer, learning_rate)
            self.LoadModelWeights(self.lm_model, file_model)
            pred = self.lm_model.predict(input).flatten()
            pred_denorm = out_scaler.inverse_transform(pred.reshape(-1, 1))
            df[file_model] = pred_denorm
        self.mean_std(df)
        df.to_excel

# %%
import os
print(os.getcwd())
# Out:
# /workspaces/Ic-Rna-2024/fuction_ensemble_3/redes-ensemble-s/Teste04

# %%
Rebuilder = Rebuild()

Rebuilder.TestNewData()
# Out:
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/layers/core/dense.py:87: UserWarning:
#
# Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:757: UserWarning:
#
# Skipping variable loading for optimizer 'adam', because it has 14 variables whereas the saved optimizer has 0 variables.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:757: UserWarning:
#
# Skipping variable loading for optimizer 'SGD', because it has 2 variables whereas the saved optimizer has 7 variables.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 385ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/layers/core/dense.py:87: UserWarning:
#
# Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:757: UserWarning:
#
# Skipping variable loading for optimizer 'adam', because it has 14 variables whereas the saved optimizer has 0 variables.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:757: UserWarning:
#
# Skipping variable loading for optimizer 'SGD', because it has 2 variables whereas the saved optimizer has 7 variables.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/layers/core/dense.py:87: UserWarning:
#
# Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:757: UserWarning:
#
# Skipping variable loading for optimizer 'adam', because it has 14 variables whereas the saved optimizer has 0 variables.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:757: UserWarning:
#
# Skipping variable loading for optimizer 'SGD', because it has 2 variables whereas the saved optimizer has 7 variables.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/layers/core/dense.py:87: UserWarning:
#
# Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:757: UserWarning:
#
# Skipping variable loading for optimizer 'adam', because it has 14 variables whereas the saved optimizer has 0 variables.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:757: UserWarning:
#
# Skipping variable loading for optimizer 'SGD', because it has 2 variables whereas the saved optimizer has 7 variables.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/layers/core/dense.py:87: UserWarning:
#
# Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:757: UserWarning:
#
# Skipping variable loading for optimizer 'adam', because it has 14 variables whereas the saved optimizer has 0 variables.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:757: UserWarning:
#
# Skipping variable loading for optimizer 'SGD', because it has 2 variables whereas the saved optimizer has 7 variables.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/layers/core/dense.py:87: UserWarning:
#
# Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:757: UserWarning:
#
# Skipping variable loading for optimizer 'adam', because it has 14 variables whereas the saved optimizer has 0 variables.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:757: UserWarning:
#
# Skipping variable loading for optimizer 'SGD', because it has 2 variables whereas the saved optimizer has 7 variables.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/layers/core/dense.py:87: UserWarning:
#
# Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:757: UserWarning:
#
# Skipping variable loading for optimizer 'adam', because it has 14 variables whereas the saved optimizer has 0 variables.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:757: UserWarning:
#
# Skipping variable loading for optimizer 'SGD', because it has 2 variables whereas the saved optimizer has 7 variables.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/layers/core/dense.py:87: UserWarning:
#
# Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:757: UserWarning:
#
# Skipping variable loading for optimizer 'adam', because it has 14 variables whereas the saved optimizer has 0 variables.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:757: UserWarning:
#
# Skipping variable loading for optimizer 'SGD', because it has 2 variables whereas the saved optimizer has 7 variables.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/layers/core/dense.py:87: UserWarning:
#
# Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:757: UserWarning:
#
# Skipping variable loading for optimizer 'adam', because it has 14 variables whereas the saved optimizer has 0 variables.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:757: UserWarning:
#
# Skipping variable loading for optimizer 'SGD', because it has 2 variables whereas the saved optimizer has 7 variables.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/layers/core/dense.py:87: UserWarning:
#
# Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:757: UserWarning:
#
# Skipping variable loading for optimizer 'adam', because it has 14 variables whereas the saved optimizer has 0 variables.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:757: UserWarning:
#
# Skipping variable loading for optimizer 'SGD', because it has 2 variables whereas the saved optimizer has 7 variables.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/layers/core/dense.py:87: UserWarning:
#
# Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:757: UserWarning:
#
# Skipping variable loading for optimizer 'adam', because it has 14 variables whereas the saved optimizer has 0 variables.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:757: UserWarning:
#
# Skipping variable loading for optimizer 'SGD', because it has 2 variables whereas the saved optimizer has 7 variables.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/layers/core/dense.py:87: UserWarning:
#
# Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:757: UserWarning:
#
# Skipping variable loading for optimizer 'adam', because it has 14 variables whereas the saved optimizer has 0 variables.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:757: UserWarning:
#
# Skipping variable loading for optimizer 'SGD', because it has 2 variables whereas the saved optimizer has 7 variables.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/layers/core/dense.py:87: UserWarning:
#
# Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:757: UserWarning:
#
# Skipping variable loading for optimizer 'adam', because it has 14 variables whereas the saved optimizer has 0 variables.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:757: UserWarning:
#
# Skipping variable loading for optimizer 'SGD', because it has 2 variables whereas the saved optimizer has 7 variables.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/layers/core/dense.py:87: UserWarning:
#
# Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:757: UserWarning:
#
# Skipping variable loading for optimizer 'adam', because it has 14 variables whereas the saved optimizer has 0 variables.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:757: UserWarning:
#
# Skipping variable loading for optimizer 'SGD', because it has 2 variables whereas the saved optimizer has 7 variables.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/layers/core/dense.py:87: UserWarning:
#
# Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:757: UserWarning:
#
# Skipping variable loading for optimizer 'adam', because it has 14 variables whereas the saved optimizer has 0 variables.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:757: UserWarning:
#
# Skipping variable loading for optimizer 'SGD', because it has 2 variables whereas the saved optimizer has 7 variables.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/layers/core/dense.py:87: UserWarning:
#
# Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:757: UserWarning:
#
# Skipping variable loading for optimizer 'adam', because it has 14 variables whereas the saved optimizer has 0 variables.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:757: UserWarning:
#
# Skipping variable loading for optimizer 'SGD', because it has 2 variables whereas the saved optimizer has 7 variables.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/layers/core/dense.py:87: UserWarning:
#
# Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:757: UserWarning:
#
# Skipping variable loading for optimizer 'adam', because it has 14 variables whereas the saved optimizer has 0 variables.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:757: UserWarning:
#
# Skipping variable loading for optimizer 'SGD', because it has 2 variables whereas the saved optimizer has 7 variables.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/layers/core/dense.py:87: UserWarning:
#
# Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:757: UserWarning:
#
# Skipping variable loading for optimizer 'adam', because it has 14 variables whereas the saved optimizer has 0 variables.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:757: UserWarning:
#
# Skipping variable loading for optimizer 'SGD', because it has 2 variables whereas the saved optimizer has 7 variables.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/layers/core/dense.py:87: UserWarning:
#
# Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:757: UserWarning:
#
# Skipping variable loading for optimizer 'adam', because it has 14 variables whereas the saved optimizer has 0 variables.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:757: UserWarning:
#
# Skipping variable loading for optimizer 'SGD', because it has 2 variables whereas the saved optimizer has 7 variables.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/layers/core/dense.py:87: UserWarning:
#
# Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:757: UserWarning:
#
# Skipping variable loading for optimizer 'adam', because it has 14 variables whereas the saved optimizer has 0 variables.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:757: UserWarning:
#
# Skipping variable loading for optimizer 'SGD', because it has 2 variables whereas the saved optimizer has 7 variables.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/layers/core/dense.py:87: UserWarning:
#
# Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:757: UserWarning:
#
# Skipping variable loading for optimizer 'adam', because it has 14 variables whereas the saved optimizer has 0 variables.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:757: UserWarning:
#
# Skipping variable loading for optimizer 'SGD', because it has 2 variables whereas the saved optimizer has 7 variables.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/layers/core/dense.py:87: UserWarning:
#
# Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:757: UserWarning:
#
# Skipping variable loading for optimizer 'adam', because it has 14 variables whereas the saved optimizer has 0 variables.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:757: UserWarning:
#
# Skipping variable loading for optimizer 'SGD', because it has 2 variables whereas the saved optimizer has 7 variables.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/layers/core/dense.py:87: UserWarning:
#
# Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:757: UserWarning:
#
# Skipping variable loading for optimizer 'adam', because it has 14 variables whereas the saved optimizer has 0 variables.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:757: UserWarning:
#
# Skipping variable loading for optimizer 'SGD', because it has 2 variables whereas the saved optimizer has 7 variables.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/layers/core/dense.py:87: UserWarning:
#
# Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:757: UserWarning:
#
# Skipping variable loading for optimizer 'adam', because it has 14 variables whereas the saved optimizer has 0 variables.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:757: UserWarning:
#
# Skipping variable loading for optimizer 'SGD', because it has 2 variables whereas the saved optimizer has 7 variables.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/layers/core/dense.py:87: UserWarning:
#
# Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:757: UserWarning:
#
# Skipping variable loading for optimizer 'adam', because it has 14 variables whereas the saved optimizer has 0 variables.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:757: UserWarning:
#
# Skipping variable loading for optimizer 'SGD', because it has 2 variables whereas the saved optimizer has 7 variables.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/layers/core/dense.py:87: UserWarning:
#
# Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:757: UserWarning:
#
# Skipping variable loading for optimizer 'adam', because it has 14 variables whereas the saved optimizer has 0 variables.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:757: UserWarning:
#
# Skipping variable loading for optimizer 'SGD', because it has 2 variables whereas the saved optimizer has 7 variables.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/layers/core/dense.py:87: UserWarning:
#
# Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:757: UserWarning:
#
# Skipping variable loading for optimizer 'adam', because it has 14 variables whereas the saved optimizer has 0 variables.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:757: UserWarning:
#
# Skipping variable loading for optimizer 'SGD', because it has 2 variables whereas the saved optimizer has 7 variables.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/layers/core/dense.py:87: UserWarning:
#
# Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:757: UserWarning:
#
# Skipping variable loading for optimizer 'adam', because it has 14 variables whereas the saved optimizer has 0 variables.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:757: UserWarning:
#
# Skipping variable loading for optimizer 'SGD', because it has 2 variables whereas the saved optimizer has 7 variables.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/layers/core/dense.py:87: UserWarning:
#
# Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:757: UserWarning:
#
# Skipping variable loading for optimizer 'adam', because it has 14 variables whereas the saved optimizer has 0 variables.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:757: UserWarning:
#
# Skipping variable loading for optimizer 'SGD', because it has 2 variables whereas the saved optimizer has 7 variables.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/layers/core/dense.py:87: UserWarning:
#
# Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:757: UserWarning:
#
# Skipping variable loading for optimizer 'adam', because it has 14 variables whereas the saved optimizer has 0 variables.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:757: UserWarning:
#
# Skipping variable loading for optimizer 'SGD', because it has 2 variables whereas the saved optimizer has 7 variables.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/layers/core/dense.py:87: UserWarning:
#
# Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:757: UserWarning:
#
# Skipping variable loading for optimizer 'adam', because it has 14 variables whereas the saved optimizer has 0 variables.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:757: UserWarning:
#
# Skipping variable loading for optimizer 'SGD', because it has 2 variables whereas the saved optimizer has 7 variables.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/layers/core/dense.py:87: UserWarning:
#
# Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:757: UserWarning:
#
# Skipping variable loading for optimizer 'adam', because it has 14 variables whereas the saved optimizer has 0 variables.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:757: UserWarning:
#
# Skipping variable loading for optimizer 'SGD', because it has 2 variables whereas the saved optimizer has 7 variables.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/layers/core/dense.py:87: UserWarning:
#
# Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:757: UserWarning:
#
# Skipping variable loading for optimizer 'adam', because it has 14 variables whereas the saved optimizer has 0 variables.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:757: UserWarning:
#
# Skipping variable loading for optimizer 'SGD', because it has 2 variables whereas the saved optimizer has 7 variables.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/layers/core/dense.py:87: UserWarning:
#
# Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:757: UserWarning:
#
# Skipping variable loading for optimizer 'adam', because it has 14 variables whereas the saved optimizer has 0 variables.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:757: UserWarning:
#
# Skipping variable loading for optimizer 'SGD', because it has 2 variables whereas the saved optimizer has 7 variables.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/layers/core/dense.py:87: UserWarning:
#
# Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:757: UserWarning:
#
# Skipping variable loading for optimizer 'adam', because it has 14 variables whereas the saved optimizer has 0 variables.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:757: UserWarning:
#
# Skipping variable loading for optimizer 'SGD', because it has 2 variables whereas the saved optimizer has 7 variables.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/layers/core/dense.py:87: UserWarning:
#
# Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:757: UserWarning:
#
# Skipping variable loading for optimizer 'adam', because it has 14 variables whereas the saved optimizer has 0 variables.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:757: UserWarning:
#
# Skipping variable loading for optimizer 'SGD', because it has 2 variables whereas the saved optimizer has 7 variables.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/layers/core/dense.py:87: UserWarning:
#
# Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:757: UserWarning:
#
# Skipping variable loading for optimizer 'adam', because it has 14 variables whereas the saved optimizer has 0 variables.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:757: UserWarning:
#
# Skipping variable loading for optimizer 'SGD', because it has 2 variables whereas the saved optimizer has 7 variables.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/layers/core/dense.py:87: UserWarning:
#
# Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:757: UserWarning:
#
# Skipping variable loading for optimizer 'adam', because it has 14 variables whereas the saved optimizer has 0 variables.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:757: UserWarning:
#
# Skipping variable loading for optimizer 'SGD', because it has 2 variables whereas the saved optimizer has 7 variables.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/layers/core/dense.py:87: UserWarning:
#
# Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:757: UserWarning:
#
# Skipping variable loading for optimizer 'adam', because it has 14 variables whereas the saved optimizer has 0 variables.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:757: UserWarning:
#
# Skipping variable loading for optimizer 'SGD', because it has 2 variables whereas the saved optimizer has 7 variables.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/layers/core/dense.py:87: UserWarning:
#
# Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:757: UserWarning:
#
# Skipping variable loading for optimizer 'adam', because it has 14 variables whereas the saved optimizer has 0 variables.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:757: UserWarning:
#
# Skipping variable loading for optimizer 'SGD', because it has 2 variables whereas the saved optimizer has 7 variables.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/layers/core/dense.py:87: UserWarning:
#
# Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:757: UserWarning:
#
# Skipping variable loading for optimizer 'adam', because it has 14 variables whereas the saved optimizer has 0 variables.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:757: UserWarning:
#
# Skipping variable loading for optimizer 'SGD', because it has 2 variables whereas the saved optimizer has 7 variables.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/layers/core/dense.py:87: UserWarning:
#
# Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:757: UserWarning:
#
# Skipping variable loading for optimizer 'adam', because it has 14 variables whereas the saved optimizer has 0 variables.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:757: UserWarning:
#
# Skipping variable loading for optimizer 'SGD', because it has 2 variables whereas the saved optimizer has 7 variables.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/layers/core/dense.py:87: UserWarning:
#
# Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:757: UserWarning:
#
# Skipping variable loading for optimizer 'adam', because it has 14 variables whereas the saved optimizer has 0 variables.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:757: UserWarning:
#
# Skipping variable loading for optimizer 'SGD', because it has 2 variables whereas the saved optimizer has 7 variables.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/layers/core/dense.py:87: UserWarning:
#
# Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:757: UserWarning:
#
# Skipping variable loading for optimizer 'adam', because it has 14 variables whereas the saved optimizer has 0 variables.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:757: UserWarning:
#
# Skipping variable loading for optimizer 'SGD', because it has 2 variables whereas the saved optimizer has 7 variables.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/layers/core/dense.py:87: UserWarning:
#
# Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:757: UserWarning:
#
# Skipping variable loading for optimizer 'adam', because it has 14 variables whereas the saved optimizer has 0 variables.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:757: UserWarning:
#
# Skipping variable loading for optimizer 'SGD', because it has 2 variables whereas the saved optimizer has 7 variables.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/layers/core/dense.py:87: UserWarning:
#
# Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:757: UserWarning:
#
# Skipping variable loading for optimizer 'adam', because it has 14 variables whereas the saved optimizer has 0 variables.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:757: UserWarning:
#
# Skipping variable loading for optimizer 'SGD', because it has 2 variables whereas the saved optimizer has 7 variables.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/layers/core/dense.py:87: UserWarning:
#
# Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:757: UserWarning:
#
# Skipping variable loading for optimizer 'adam', because it has 14 variables whereas the saved optimizer has 0 variables.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:757: UserWarning:
#
# Skipping variable loading for optimizer 'SGD', because it has 2 variables whereas the saved optimizer has 7 variables.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/layers/core/dense.py:87: UserWarning:
#
# Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:757: UserWarning:
#
# Skipping variable loading for optimizer 'adam', because it has 14 variables whereas the saved optimizer has 0 variables.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:757: UserWarning:
#
# Skipping variable loading for optimizer 'SGD', because it has 2 variables whereas the saved optimizer has 7 variables.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/layers/core/dense.py:87: UserWarning:
#
# Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:757: UserWarning:
#
# Skipping variable loading for optimizer 'adam', because it has 14 variables whereas the saved optimizer has 0 variables.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:757: UserWarning:
#
# Skipping variable loading for optimizer 'SGD', because it has 2 variables whereas the saved optimizer has 7 variables.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/layers/core/dense.py:87: UserWarning:
#
# Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:757: UserWarning:
#
# Skipping variable loading for optimizer 'adam', because it has 14 variables whereas the saved optimizer has 0 variables.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:757: UserWarning:
#
# Skipping variable loading for optimizer 'SGD', because it has 2 variables whereas the saved optimizer has 7 variables.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/layers/core/dense.py:87: UserWarning:
#
# Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:757: UserWarning:
#
# Skipping variable loading for optimizer 'adam', because it has 14 variables whereas the saved optimizer has 0 variables.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:757: UserWarning:
#
# Skipping variable loading for optimizer 'SGD', because it has 2 variables whereas the saved optimizer has 7 variables.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/layers/core/dense.py:87: UserWarning:
#
# Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:757: UserWarning:
#
# Skipping variable loading for optimizer 'adam', because it has 14 variables whereas the saved optimizer has 0 variables.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:757: UserWarning:
#
# Skipping variable loading for optimizer 'SGD', because it has 2 variables whereas the saved optimizer has 7 variables.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/layers/core/dense.py:87: UserWarning:
#
# Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:757: UserWarning:
#
# Skipping variable loading for optimizer 'adam', because it has 14 variables whereas the saved optimizer has 0 variables.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:757: UserWarning:
#
# Skipping variable loading for optimizer 'SGD', because it has 2 variables whereas the saved optimizer has 7 variables.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/layers/core/dense.py:87: UserWarning:
#
# Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:757: UserWarning:
#
# Skipping variable loading for optimizer 'adam', because it has 14 variables whereas the saved optimizer has 0 variables.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:757: UserWarning:
#
# Skipping variable loading for optimizer 'SGD', because it has 2 variables whereas the saved optimizer has 7 variables.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/layers/core/dense.py:87: UserWarning:
#
# Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:757: UserWarning:
#
# Skipping variable loading for optimizer 'adam', because it has 14 variables whereas the saved optimizer has 0 variables.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:757: UserWarning:
#
# Skipping variable loading for optimizer 'SGD', because it has 2 variables whereas the saved optimizer has 7 variables.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/layers/core/dense.py:87: UserWarning:
#
# Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:757: UserWarning:
#
# Skipping variable loading for optimizer 'adam', because it has 14 variables whereas the saved optimizer has 0 variables.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:757: UserWarning:
#
# Skipping variable loading for optimizer 'SGD', because it has 2 variables whereas the saved optimizer has 7 variables.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/layers/core/dense.py:87: UserWarning:
#
# Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:757: UserWarning:
#
# Skipping variable loading for optimizer 'adam', because it has 14 variables whereas the saved optimizer has 0 variables.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:757: UserWarning:
#
# Skipping variable loading for optimizer 'SGD', because it has 2 variables whereas the saved optimizer has 7 variables.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/layers/core/dense.py:87: UserWarning:
#
# Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:757: UserWarning:
#
# Skipping variable loading for optimizer 'adam', because it has 14 variables whereas the saved optimizer has 0 variables.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:757: UserWarning:
#
# Skipping variable loading for optimizer 'SGD', because it has 2 variables whereas the saved optimizer has 7 variables.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/layers/core/dense.py:87: UserWarning:
#
# Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:757: UserWarning:
#
# Skipping variable loading for optimizer 'adam', because it has 14 variables whereas the saved optimizer has 0 variables.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:757: UserWarning:
#
# Skipping variable loading for optimizer 'SGD', because it has 2 variables whereas the saved optimizer has 7 variables.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/layers/core/dense.py:87: UserWarning:
#
# Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:757: UserWarning:
#
# Skipping variable loading for optimizer 'adam', because it has 14 variables whereas the saved optimizer has 0 variables.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:757: UserWarning:
#
# Skipping variable loading for optimizer 'SGD', because it has 2 variables whereas the saved optimizer has 7 variables.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/layers/core/dense.py:87: UserWarning:
#
# Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:757: UserWarning:
#
# Skipping variable loading for optimizer 'adam', because it has 14 variables whereas the saved optimizer has 0 variables.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:757: UserWarning:
#
# Skipping variable loading for optimizer 'SGD', because it has 2 variables whereas the saved optimizer has 7 variables.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/layers/core/dense.py:87: UserWarning:
#
# ...
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/layers/core/dense.py:87: UserWarning:
#
# Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:757: UserWarning:
#
# Skipping variable loading for optimizer 'adam', because it has 14 variables whereas the saved optimizer has 0 variables.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:757: UserWarning:
#
# Skipping variable loading for optimizer 'SGD', because it has 2 variables whereas the saved optimizer has 7 variables.
#
# /tmp/ipykernel_4113/4134661654.py:146: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/layers/core/dense.py:87: UserWarning:
#
# Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:757: UserWarning:
#
# Skipping variable loading for optimizer 'adam', because it has 14 variables whereas the saved optimizer has 0 variables.
#
# /workspaces/IC-RNA-2025/.conda/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:757: UserWarning:
#
# Skipping variable loading for optimizer 'SGD', because it has 2 variables whereas the saved optimizer has 7 variables.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
